# %%
import pandas as pd

# %%
df = pd.read_csv('movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
df['name'].nunique()
# Out:
# 7512

# %%
# Checking if any rows are duplicated --> no rows are duplicated
df.duplicated().sum()
# Out:
# 0

# %%
# Made a new column named country by taking countries from the released columns 
df['country'] = df['released'].str.extract(r'\(([^)]+)\)')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star        country      budget  \
# ...

# %%
# dropped released columns as we have the year from the year column and country from the country column 
df.drop('released', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#    score      votes         director                   writer            star  \
# 0    8.4   927000.0  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2    8.7  1200000.0   Irvin Kershner           Leigh Brackett     Mark Hamill
# 3    7.7   221000.0     Jim Abrahams             Jim Abrahams     Robert Hays
# 4    7.3   108000.0     Harold Ramis       Brian Doyle-Murray     Chevy Chase
#
# ...

# %%
df.tail()
# Out:
#                name rating   genre  year  score  votes       director  \
# 7663   More to Life    NaN   Drama  2020    3.1   18.0  Joseph Ebanks
# 7664    Dream Round    NaN  Comedy  2020    4.7   36.0   Dusty Dukatz
# 7665  Saving Mbango    NaN   Drama  2020    5.7   29.0   Nkanya Nkwai
# 7666   It's Just Us    NaN   Drama  2020    NaN    NaN  James Randall
# 7667      Tee em el    NaN  Horror  2020    5.7    7.0   Pereko Mosia
#
#              writer              star        country   budget  gross  \
# 7663  Joseph Ebanks      Shannon Bond  United States   7000.0    NaN
# 7664    Lisa Huston  Michael Saquella  United States      NaN    NaN
# 7665   Lynno Lovert      Onyama Laura       Cameroon  58750.0    NaN
# 7666  James Randall     Christina Roz  United States  15000.0    NaN
# 7667   Pereko Mosia  Siyabonga Mabaso  United States      NaN    NaN
#
#                         company  runtime
# 7663                        NaN     90.0
# 7664  Cactus Blue Entertainment     90.0
# ...

# %%
def decade(row):
    if (row['year'] >= 1980) & (row['year'] < 1990):
        return '80s'
    elif (row['year'] >= 1990) & (row['year'] < 2000):
        return '90s'
    elif (row['year'] >= 2000) & (row['year'] < 2010):
        return '0s'
    else:
        return '10s'

# %%
def decades(row):
    if (row['year'] >= 1980) & (row['year'] < 1990):
        return '80s'
    elif (row['year'] >= 1990) & (row['year'] < 2000):
        return '90s'
    elif (row['year'] >= 2000) & (row['year'] < 2010):
        return '0s'
    else:
        return '10s'

# %%
df['decade'] = df.apply(decades, axis=1)

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#    score      votes         director                   writer            star  \
# 0    8.4   927000.0  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2    8.7  1200000.0   Irvin Kershner           Leigh Brackett     Mark Hamill
# 3    7.7   221000.0     Jim Abrahams             Jim Abrahams     Robert Hays
# 4    7.3   108000.0     Harold Ramis       Brian Doyle-Murray     Chevy Chase
#
# ...

# %%
dropped_rows = df[df['year'] == 2020].index

# %%
dropped_rows
# Out:
#                            name     rating      genre  year  score     votes  \
# 7643                      Tenet      PG-13     Action  2020    7.4  387000.0
# 7644          Wonder Woman 1984      PG-13     Action  2020    5.4  217000.0
# 7645              Birds of Prey          R     Action  2020    6.1  190000.0
# 7646          The Invisible Man          R      Drama  2020    7.1  186000.0
# 7647                     Onward         PG  Animation  2020    7.4  120000.0
# 7648          Bad Boys for Life          R     Action  2020    6.6  140000.0
# 7649         Sonic the Hedgehog         PG     Action  2020    6.5  102000.0
# 7650                   Dolittle         PG  Adventure  2020    5.6   53000.0
# 7651       The Call of the Wild         PG  Adventure  2020    6.8   42000.0
# 7652          The Eight Hundred  Not Rated     Action  2020    6.8    3700.0
# 7653                 The Quarry          R      Crime  2020    5.4    2400.0
# ...

# %%
df.drop(dropped_rows, axis=0, inplace=True)

# %%
df.tail()
# Out:
#                                         name     rating   genre  year  score  \
# 7638  Chasing the Dragon II: Wild Wild Bunch  Not Rated  Action  2019    5.8
# 7639                      Round of Your Life        NaN  Family  2019    4.6
# 7640                               El Coyote          R  Action  2019    3.0
# 7641                By Light of Desert Night        NaN   Drama  2019    4.8
# 7642                        A Brother's Love        NaN   Drama  2019    6.8
#
#       votes            director              writer                  star  \
# 7638  523.0          Jason Kwan        Koon-Nam Lui     Tony Ka Fai Leung
# 7639  150.0  Dylan Thomas Ellis        Tim Ogletree            Cole Allen
# 7640  122.0   Jeffrey Nicholson   Jeffrey Nicholson      Michael Saquella
# 7641  373.0  David Stuart Snell  David Stuart Snell      Alexandra Bokova
# 7642  869.0        Monia Chokri        Monia Chokri  Anne-Élisabeth Bossé
#
# ...
